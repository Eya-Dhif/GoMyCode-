# %% [markdown]
# <a href="https://colab.research.google.com/github/Eya-Dhif/GoMyCode-/blob/main/part3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tkinter as tk
from tkinter import messagebox

window = tk.Tk()
window.title("TIC-TAC-TOE")
window.geometry("300x150")

digits= [1,2,3,4,5,6,7,8,9]
mark=''
count=0
panels = ['panel', 1, 2, 3, 4, 5, 6, 7, 8, 9]

def win():
    pass

def handle_button_click(button):
    global count, mark, digits

    if button["text"] != "":
      print("Invalid Move", "the position is already taken")
      return

    count += 1
    mark='X' if count % 2 == 0 else'O'
    button.config(text=mark)

#handle different digit values from 1 to 9
    if digit not in digits:
      print('the digit you entered is not valid')

    if digit==1 and 1 in digits:
      digits.remove(1)
      button1.config(text=mark)
    elif digit==2 and 2 in digits:
      digits.remove(2)
      button2.config(text=mark)
    elif digit==3 and 3 in digits:
      digits.remove(3)
      button3.config(text=mark)
    elif digit==4 and 4 in digits:
      digits.remove(4)
      button4.config(text=mark)
    elif digit==5 and 5 in digits:
      digits.remove(5)
      button5.config(text=mark)
    elif digit==6 and 6 in digits:
      digits.remove(6)
      button6.config(text=mark)
    elif digit==7 and 7 in digits:
      digits.remove(7)
      button7.config(text=mark)
    elif digit==8 and 8 in digits:
      digits.remove(8)
      button8.config(text=mark)
    elif digit==9 and 9 in digits:
      digits.remove(9)
      button9.config(text=mark)
    else:
      count -= 1
# Check if the current player has won
    if win():
        winner= "player1" if mark=='X' else "player2"
        print("Game Over", "(winner) wins")
        window.destroy()
    elif count > 8:
        print("Game Over", "It's a tie")
        window.destroy()

# Create labels to display players' symbols (X and O)
player1_label = tk.Label(window, text="Player1 (X)")
player1_label.grid(row=0, column=0, columnspan=3)

player2_label = tk.Label(window, text="Player2 (O)")
player2_label.grid(row=4, column=0, columnspan=3)

#Create buttons for each cell of the Tic-Tac-Toe board
buttons = []

for i in range(3):
    row_buttons = []
    for j in range(3):
      button = tk.Button(window, text="", command=lambda row=i, col=j: handle_button_click(row, col), width=10, height=3)
      button.grid(row=i + 1, column=j)
      row_buttons.append(button)
    buttons.append(row_buttons)


window.mainloop()
